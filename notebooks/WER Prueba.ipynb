# %%
# !pip install jiwer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 18.7 MB/s eta 0:00:00
# ...

# %%
from jiwer import wer

with open("Libro 1_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 1_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 1:", error)

with open("Libro 2_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 2_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 2:", error)

with open("Libro 3_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 3_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 3:", error)

with open("Libro 4_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 4_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 4:", error)

with open("Libro 5_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 5_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 5:", error)

with open("Libro 6_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 6_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 6:", error)

with open("Libro 7_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 7_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 7:", error)

with open("Libro 8_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 8_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 8:", error)

with open("Libro 9_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 9_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 9:", error)

with open("Libro 10_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 10_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 10:", error)
# Out:
# WER Libro 1: 0.003714020427112349
# WER Libro 2: 0.001594896331738437
# WER Libro 3: 0.0006720430107526882
# WER Libro 4: 0.013066202090592335
# WER Libro 5: 0.005797101449275362
# WER Libro 6: 0.0038910505836575876
# WER Libro 7: 0.0037209302325581397
# WER Libro 8: 0.004226096143687269
# WER Libro 9: 0.00618921308576481
# WER Libro 10: 0.0

# %%
from jiwer import wer

with open("Libro 4_sam_5p - copia.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 4_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 5 copia:", error)
# Out:
# WER Libro 5 copia: 0.0017421602787456446

# %%
from jiwer import wer

with open("Libro 11_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 11_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 11:", error)

with open("Libro 12_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 12_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 12:", error)

with open("Libro 13_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 13_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 13:", error)

with open("Libro 14_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 14_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 14:", error)

with open("Libro 15_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 15_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 15:", error)

with open("Libro 16_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 16_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 16:", error)

with open("Libro 17_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 17_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 17:", error)

with open("Libro 18_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 18_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 18:", error)

with open("Libro 19_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 19_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 19:", error)

with open("Libro 20_sam_5p.txt", "r", encoding="utf-8") as f:
    sample = f.read()

with open("Libro 20_GT_5p.txt", "r", encoding="utf-8") as f:
    gt = f.read()

error = wer(gt, sample)

print("WER Libro 20:", error)
# Out:
# WER Libro 11: 0.0035063113604488078
# WER Libro 12: 0.0035629453681710215
# WER Libro 13: 0.0020422055820285907
# WER Libro 14: 0.0015503875968992248
# WER Libro 15: 0.005529953917050691
# WER Libro 16: 0.0013937282229965157
# WER Libro 17: 0.002073613271124935
# WER Libro 18: 0.003232062055591467
# WER Libro 19: 0.0044365572315882874
# WER Libro 20: 0.0

# %%
# Leer el archivo original
text = open("Libro 1_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 1_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 1_sam_20p.txt")

# Leer el archivo original
text = open("Libro 2_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 2_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 2_sam_20p.txt")

# Leer el archivo original
text = open("Libro 3_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 3_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 3_sam_20p.txt")

# Leer el archivo original
text = open("Libro 4_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 4_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 4_sam_20p.txt")

# Leer el archivo original
text = open("Libro 5_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 5_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 5_sam_20p.txt")

# Leer el archivo original
text = open("Libro 6_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 6_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 6_sam_20p.txt")

# Leer el archivo original
text = open("Libro 7_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 7_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 7_sam_20p.txt")

# Leer el archivo original
text = open("Libro 8_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 8_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 8_sam_20p.txt")

# Leer el archivo original
text = open("Libro 9_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 9_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 9_sam_20p.txt")

# Leer el archivo original
text = open("Libro 10_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 10_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 10_sam_20p.txt")

# %%
# Leer el archivo original
text = open("Libro 11_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 11_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 11_sam_20p.txt")

# Leer el archivo original
text = open("Libro 12_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 12_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 12_sam_20p.txt")

# Leer el archivo original
text = open("Libro 13_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 13_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 13_sam_20p.txt")

# Leer el archivo original
text = open("Libro 14_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 14_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 14_sam_20p.txt")

# Leer el archivo original
text = open("Libro 15_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 15_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 15_sam_20p.txt")

# Leer el archivo original
text = open("Libro 16_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 16_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 16_sam_20p.txt")

# Leer el archivo original
text = open("Libro 17_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 17_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 17_sam_20p.txt")

# Leer el archivo original
text = open("Libro 18_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 18_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 18_sam_20p.txt")

# Leer el archivo original
text = open("Libro 19_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 19_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 19_sam_20p.txt")

# Leer el archivo original
text = open("Libro 20_norm.txt", encoding="utf-8").read()

# Separar en palabras
words = text.split()

# Seleccionar primeras ~5000 palabras (ajusta si quieres)
n = 5000
sample_words = words[:n]

# Unir de nuevo en texto
sample_text = " ".join(sample_words)

# Guardar en nuevo archivo
with open("libro 20_sam_20p.txt", "w", encoding="utf-8") as f:
    f.write(sample_text)

# Descargar al ordenador
from google.colab import files
files.download("libro 20_sam_20p.txt")

# %%
import pandas as pd

# cargar texto
text = open("libro 1_sam_20p.txt", encoding="utf-8").read()

# dividir en palabras
words = text.split()

# crear pares
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# dataframe
df = pd.DataFrame(pairs, columns=["Source", "Target"])

# guardar
df.to_csv("edges.csv", index=False)

# descargar
from google.colab import files
files.download("edges.csv")

# %%
import pandas as pd

# Leer archivo
text = open("libro 1_sam_20p.txt", encoding="utf-8").read()

# Convertir a palabras
words = text.split()

# Stopwords básicas en español
stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

# Filtrar palabras
words = [w for w in words if w.lower() not in stopwords]

# Crear pares de palabras consecutivas
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Crear DataFrame
df = pd.DataFrame(pairs, columns=["Source", "Target"])

# Guardar CSV
df.to_csv("edges_clean.csv", index=False)

# Descargar
from google.colab import files
files.download("edges_clean.csv")

# %%
import pandas as pd

# Leer archivo
text = open("libro 1_sam_20p.txt", encoding="utf-8").read()

# Convertir a palabras
words = text.split()

# Stopwords básicas en español
stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

# Filtrar palabras
words = [w for w in words if w.lower() not in stopwords]

# Crear pares de palabras consecutivas
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Crear DataFrame
df = pd.DataFrame(pairs, columns=["Source", "Target"])

# Guardar CSV
df.to_csv("edges_clean11.csv", index=False)

# Descargar
from google.colab import files
files.download("edges_clean11.csv")

# %% [markdown]
# Aquí empiezo a crear los edge limpios con stopwords  clean 1 y añadiendo más stopwords clean . Primero lo hacemos con los ejemplos de 20 páginas del libro 1 y 11.

# %%
import pandas as pd

text = open("libro 1_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 1_clean1.csv", index=False)

from google.colab import files
files.download("edges 1_clean1.csv")

# %%
import pandas as pd

text = open("libro 1_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

stopwords_extra = {
    "no","si","me","ya","muy","más","menos","todo","toda","todos","todas",
    "esto","eso","aquí","allí","también","solo","sólo","tan","como","porque",
    "aunque","pues","entonces","donde","cuando","quien"
}

stopwords = stopwords.union(stopwords_extra)

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 1_clean2.csv", index=False)

from google.colab import files
files.download("edges 1_clean2.csv")

# %%
import pandas as pd

text = open("libro 11_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 11_clean1.csv", index=False)

from google.colab import files
files.download("edges 11_clean1.csv")

# %%
import pandas as pd

text = open("libro 11_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

stopwords_extra = {
    "no","si","me","ya","muy","más","menos","todo","toda","todos","todas",
    "esto","eso","aquí","allí","también","solo","sólo","tan","como","porque",
    "aunque","pues","entonces","donde","cuando","quien"
}

stopwords = stopwords.union(stopwords_extra)

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 11_clean2.csv", index=False)

from google.colab import files
files.download("edges 11_clean2.csv")

# %% [markdown]
# Añado el libro 2 y el libro 12

# %%
import pandas as pd

text = open("libro 2_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 2_clean1.csv", index=False)

from google.colab import files
files.download("edges 2_clean1.csv")

# %%
import pandas as pd

text = open("libro 2_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

stopwords_extra = {
    "no","si","me","ya","muy","más","menos","todo","toda","todos","todas",
    "esto","eso","aquí","allí","también","solo","sólo","tan","como","porque",
    "aunque","pues","entonces","donde","cuando","quien"
}

stopwords = stopwords.union(stopwords_extra)

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 2_clean2.csv", index=False)

from google.colab import files
files.download("edges 2_clean2.csv")

# %%
import pandas as pd

text = open("libro 12_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 12_clean1.csv", index=False)

from google.colab import files
files.download("edges 12_clean1.csv")

# %%
import pandas as pd

text = open("libro 12_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

stopwords_extra = {
    "no","si","me","ya","muy","más","menos","todo","toda","todos","todas",
    "esto","eso","aquí","allí","también","solo","sólo","tan","como","porque",
    "aunque","pues","entonces","donde","cuando","quien"
}

stopwords = stopwords.union(stopwords_extra)

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 12_clean2.csv", index=False)

from google.colab import files
files.download("edges 12_clean2.csv")

# %% [markdown]
# Lo mismo para los libros 20p libro3 y libro13

# %%
import pandas as pd

text = open("libro 3_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 3_clean1.csv", index=False)

from google.colab import files
files.download("edges 3_clean1.csv")

# %%
import pandas as pd

text = open("libro 3_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

stopwords_extra = {
    "no","si","me","ya","muy","más","menos","todo","toda","todos","todas",
    "esto","eso","aquí","allí","también","solo","sólo","tan","como","porque",
    "aunque","pues","entonces","donde","cuando","quien"
}

stopwords = stopwords.union(stopwords_extra)

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 3_clean2.csv", index=False)

from google.colab import files
files.download("edges 3_clean2.csv")

# %%
import pandas as pd

text = open("libro 13_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 13_clean1.csv", index=False)

from google.colab import files
files.download("edges 13_clean1.csv")

# %%
import pandas as pd

text = open("libro 13_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

stopwords_extra = {
    "no","si","me","ya","muy","más","menos","todo","toda","todos","todas",
    "esto","eso","aquí","allí","también","solo","sólo","tan","como","porque",
    "aunque","pues","entonces","donde","cuando","quien"
}

stopwords = stopwords.union(stopwords_extra)

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 13_clean2.csv", index=False)

from google.colab import files
files.download("edges 13_clean2.csv")

# %% [markdown]
# Libros 4 y 14

# %%
import pandas as pd

text = open("libro 4_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 4_clean1.csv", index=False)

from google.colab import files
files.download("edges 4_clean1.csv")

# %%
import pandas as pd

text = open("libro 4_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

stopwords_extra = {
    "no","si","me","ya","muy","más","menos","todo","toda","todos","todas",
    "esto","eso","aquí","allí","también","solo","sólo","tan","como","porque",
    "aunque","pues","entonces","donde","cuando","quien"
}

stopwords = stopwords.union(stopwords_extra)

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 4_clean2.csv", index=False)

from google.colab import files
files.download("edges 4_clean2.csv")

# %%
import pandas as pd

text = open("libro 14_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 14_clean1.csv", index=False)

from google.colab import files
files.download("edges 14_clean1.csv")

# %%
import pandas as pd

text = open("libro 14_sam_20p.txt", encoding="utf-8").read()
words = text.split()

stopwords = {
    "de","la","el","y","que","en","a","los","las","un","una",
    "con","por","para","es","al","del","se","su","sus","le","lo"
}

stopwords_extra = {
    "no","si","me","ya","muy","más","menos","todo","toda","todos","todas",
    "esto","eso","aquí","allí","también","solo","sólo","tan","como","porque",
    "aunque","pues","entonces","donde","cuando","quien"
}

stopwords = stopwords.union(stopwords_extra)

words = [w for w in words if w.lower() not in stopwords]

pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 14_clean2.csv", index=False)

from google.colab import files
files.download("edges 14_clean2.csv")

# %% [markdown]
# Hago un edge definitivo. Libro 1 y libro 11

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 1_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 1_definitivo.csv", index=False)

from google.colab import files
files.download("edges 1_definitivo.csv")

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 11_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 11_definitivo.csv", index=False)

from google.colab import files
files.download("edges 11_definitivo.csv")

# %% [markdown]
# Sigo con los clean definitivos voy por parejas. libro 2 y libro 12

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 2_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 2_definitivo.csv", index=False)

from google.colab import files
files.download("edges 2_definitivo.csv")

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 12_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 12_definitivo.csv", index=False)

from google.colab import files
files.download("edges 12_definitivo.csv")

# %% [markdown]
# Libro 3 y libro 13

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 3_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 3_definitivo.csv", index=False)

from google.colab import files
files.download("edges 3_definitivo.csv")

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 13_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 13_definitivo.csv", index=False)

from google.colab import files
files.download("edges 13_definitivo.csv")

# %% [markdown]
# Libro 4 y libro 14

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 4_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 4_definitivo.csv", index=False)

from google.colab import files
files.download("edges 4_definitivo.csv")

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 14_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 14_definitivo.csv", index=False)

from google.colab import files
files.download("edges 14_definitivo.csv")

# %% [markdown]
# Libro 5 y libro 15

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 5_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 5_definitivo.csv", index=False)

from google.colab import files
files.download("edges 5_definitivo.csv")

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 15_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 15_definitivo.csv", index=False)

from google.colab import files
files.download("edges 15_definitivo.csv")

# %% [markdown]
# Libro 6 y libro 16

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 6_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 6_definitivo.csv", index=False)

from google.colab import files
files.download("edges 6_definitivo.csv")

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 16_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 16_definitivo.csv", index=False)

from google.colab import files
files.download("edges 16_definitivo.csv")

# %% [markdown]
# Libro 7 y libro 17

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 7_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 7_definitivo.csv", index=False)

from google.colab import files
files.download("edges 7_definitivo.csv")

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 17_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 17_definitivo.csv", index=False)

from google.colab import files
files.download("edges 17_definitivo.csv")

# %% [markdown]
# Libro 8 y libro 18

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 8_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 8_definitivo.csv", index=False)

from google.colab import files
files.download("edges 8_definitivo.csv")

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 18_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 18_definitivo.csv", index=False)

from google.colab import files
files.download("edges 18_definitivo.csv")

# %% [markdown]
# Libro 9 y libro 19

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 9_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 9_definitivo.csv", index=False)

from google.colab import files
files.download("edges 9_definitivo.csv")

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 19_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 19_definitivo.csv", index=False)

from google.colab import files
files.download("edges 19_definitivo.csv")

# %% [markdown]
# Libro 10 y libro 20

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 10_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 10_definitivo.csv", index=False)

from google.colab import files
files.download("edges 10_definitivo.csv")

# %%
import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# Leer archivo
text = open("libro 20_sam_20p.txt", encoding="utf-8").read()

# Minúsculas
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# Tokenizar simple
words = text.split()

# Stopwords NLP + algunas extra tuyas
stopwords_extra = {
    "si", "sí", "ya", "tan", "solo", "sólo", "aun", "aún",
    "muy", "porque", "pues", "entonces", "aquí", "allí", "pero", "luego", "ahora"
}
stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar tokens
words = [w for w in words if w not in stopwords and len(w) > 2]

# Crear pares consecutivos
pairs = [(words[i], words[i+1]) for i in range(len(words)-1)]

# Guardar CSV
df = pd.DataFrame(pairs, columns=["Source", "Target"])
df.to_csv("edges 20_definitivo.csv", index=False)

from google.colab import files
files.download("edges 20_definitivo.csv")

# %% [markdown]
# Paso a crear los edges con ventana de 5 en lugar de solo contigüidad.

# %%
# Instalar spaCy (solo la primera vez)
# !pip install spacy

import re
import pandas as pd
from spacy.lang.es.stop_words import STOP_WORDS

# -------------------------
# 1. Cargar texto
# -------------------------
text = open("libro 1_sam_20p.txt", encoding="utf-8").read()

# -------------------------
# 2. Normalización
# -------------------------
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# -------------------------
# 3. Tokenización
# -------------------------
words = text.split()

# -------------------------
# 4. Stopwords
# -------------------------
stopwords_extra = {
    "si","sí","ya","tan","solo","sólo","aun","aún","muy",
    "porque","pues","entonces","aquí","allí","también","pero",
    "dijo","dice","hacer","hace","así","ser","estar"
}

stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar palabras
words = [w for w in words if w not in stopwords and len(w) > 2]

# -------------------------
# 5. Crear aristas (ventana = 5)
# -------------------------
window = 5
pairs = []

for i in range(len(words)):
    for j in range(i+1, min(i+window, len(words))):
        pairs.append((words[i], words[j]))

# -------------------------
# 6. Crear CSV
# -------------------------
df = pd.DataFrame(pairs, columns=["Source", "Target"])

df.to_csv("edges 1_window5.csv", index=False)

# -------------------------
# 7. Descargar
# -------------------------
from google.colab import files
files.download("edges 1_window5.csv")

# %%
# -------------------------
# 1. Cargar texto
# -------------------------
text = open("libro 11_sam_20p.txt", encoding="utf-8").read()

# -------------------------
# 2. Normalización
# -------------------------
text = text.lower()

# Quitar puntuación y números
text = re.sub(r"[^\w\sáéíóúüñ]", " ", text)
text = re.sub(r"\d+", " ", text)

# -------------------------
# 3. Tokenización
# -------------------------
words = text.split()

# -------------------------
# 4. Stopwords
# -------------------------
stopwords_extra = {
    "si","sí","ya","tan","solo","sólo","aun","aún","muy",
    "porque","pues","entonces","aquí","allí","también","pero",
    "dijo","dice","hacer","hace","así","ser","estar"
}

stopwords = STOP_WORDS.union(stopwords_extra)

# Filtrar palabras
words = [w for w in words if w not in stopwords and len(w) > 2]

# -------------------------
# 5. Crear aristas (ventana = 5)
# -------------------------
window = 5
pairs = []

for i in range(len(words)):
    for j in range(i+1, min(i+window, len(words))):
        pairs.append((words[i], words[j]))

# -------------------------
# 6. Crear CSV
# -------------------------
df = pd.DataFrame(pairs, columns=["Source", "Target"])

df.to_csv("edges 11_window5.csv", index=False)

# -------------------------
# 7. Descargar
# -------------------------
from google.colab import files
files.download("edges 11_window5.csv")
